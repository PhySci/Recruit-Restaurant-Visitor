# %% [markdown]
# ## Recruit Restaurant Visitor Forecasting
#
# In this competition, you are provided a time-series forecasting problem centered around restaurant visitors. The data comes from two separate sites:
#
#     Hot Pepper Gourmet (hpg): similar to Yelp, here users can search restaurants and also make a reservation online
#     AirREGI / Restaurant Board (air): similar to Square, a reservation control and cash register system
#
# You must use the reservations, visits, and other information from these sites to forecast future restaurant visitor totals on a given date. The training data covers the dates from 2016 until April 2017. The test set covers the last week of April and May of 2017. The test set is split based on time (the public fold coming first, the private fold following the public) and covers a chosen subset of the air restaurants. Note that the test set intentionally spans a holiday week in Japan called the "Golden Week."
#
# There are days in the test set where the restaurant were closed and had no visitors. These are ignored in scoring. The training set omits days where the restaurants were closed.
# File Descriptions
#
# This is a relational dataset from two systems. Each file is prefaced with the source (either air_ or hpg_) to indicate its origin. Each restaurant has a unique air_store_id and hpg_store_id. Note that not all restaurants are covered by both systems, and that you have been provided data beyond the restaurants for which you must forecast. Latitudes and Longitudes are not exact to discourage de-identification of restaurants.
#
# ##### air_reserve.csv
#
# This file contains reservations made in the air system. Note that the reserve_datetime indicates the time when the reservation was created, whereas the visit_datetime is the time in the future where the visit will occur.
#
#     air_store_id - the restaurant's id in the air system
#     visit_datetime - the time of the reservation
#     reserve_datetime - the time the reservation was made
#     reserve_visitors - the number of visitors for that reservation
#
# ##### hpg_reserve.csv
#
# This file contains reservations made in the hpg system.
#
#     hpg_store_id - the restaurant's id in the hpg system
#     visit_datetime - the time of the reservation
#     reserve_datetime - the time the reservation was made
#     reserve_visitors - the number of visitors for that reservation
#
# ##### air_store_info.csv
#
# This file contains information about select air restaurants. Column names and contents are self-explanatory.
#
#     air_store_id
#     air_genre_name
#     air_area_name
#     latitude
#     longitude
#
# Note: latitude and longitude are the latitude and longitude of the area to which the store belongs
#
# ##### hpg_store_info.csv
#
# This file contains information about select hpg restaurants. Column names and contents are self-explanatory.
#
#     hpg_store_id
#     hpg_genre_name
#     hpg_area_name
#     latitude
#     longitude
#
# Note: latitude and longitude are the latitude and longitude of the area to which the store belongs
#
# ##### store_id_relation.csv
#
# This file allows you to join select restaurants that have both the air and hpg system.
#
#     hpg_store_id
#     air_store_id
#
# ##### air_visit_data.csv
#
# This file contains historical visit data for the air restaurants.
#
#     air_store_id
#     visit_date - the date
#     visitors - the number of visitors to the restaurant on the date
#
# ##### sample_submission.csv
#
# This file shows a submission in the correct format, including the days for which you must forecast.
#
#     id - the id is formed by concatenating the air_store_id and visit_date with an underscore
#     visitors- the number of visitors forecasted for the store and date combination
#
# ##### date_info.csv
#
# This file gives basic information about the calendar dates in the dataset.
#
#     calendar_date
#     day_of_week
#     holiday_flg - is the day a holiday in Japan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Load air reserve, visit and store info

# %%
air_reserve_df = pd.read_csv('./data/air_reserve.csv',
                             parse_dates = ['visit_datetime','reserve_datetime'])
air_reserve_df.head()
# Out:
#            air_store_id      visit_datetime    reserve_datetime  \
# 0  air_877f79706adbfb06 2016-01-01 19:00:00 2016-01-01 16:00:00
# 1  air_db4b38ebe7a7ceff 2016-01-01 19:00:00 2016-01-01 19:00:00
# 2  air_db4b38ebe7a7ceff 2016-01-01 19:00:00 2016-01-01 19:00:00
# 3  air_877f79706adbfb06 2016-01-01 20:00:00 2016-01-01 16:00:00
# 4  air_db80363d35f10926 2016-01-01 20:00:00 2016-01-01 01:00:00
#
#    reserve_visitors
# 0                 1
# 1                 3
# 2                 6
# 3                 2
# 4                 5

# %%
air_info_df = pd.read_csv('./data/air_store_info.csv', index_col='air_store_id')
air_info_df.head()
# Out:
#                       air_genre_name                 air_area_name   latitude  \
# air_store_id
# air_0f0cdeee6c9bf3d7  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124
# air_7cc17a324ae5c7dc  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124
# air_fee8dcf4d619598e  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124
# air_a17f0778617c76e2  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124
# air_83db5aff8f50478e  Italian/French  Tōkyō-to Minato-ku Shibakōen  35.658068
#
#                        longitude
# air_store_id
# air_0f0cdeee6c9bf3d7  135.197852
# air_7cc17a324ae5c7dc  135.197852
# air_fee8dcf4d619598e  135.197852
# air_a17f0778617c76e2  135.197852
# air_83db5aff8f50478e  139.751599

# %%
air_visit_df = pd.read_csv('./data/air_visit_data.csv',
                          parse_dates=['visit_date'])
air_visit_df.head()
# Out:
#            air_store_id visit_date  visitors
# 0  air_ba937bf13d40fb24 2016-01-13        25
# 1  air_ba937bf13d40fb24 2016-01-14        32
# 2  air_ba937bf13d40fb24 2016-01-15        29
# 3  air_ba937bf13d40fb24 2016-01-16        22
# 4  air_ba937bf13d40fb24 2016-01-18         6

# %% [markdown]
# Количество уникальных ресторанов

# %%
len(air_visit_df.air_store_id.unique())
# Out:
# 829

# %%
air_store_group = air_visit_df.groupby("air_store_id")
air_reserve_group = air_reserve_df.groupby("air_store_id")

# %%
air_stores = list(air_store_group.groups.keys())

# %%
ind = 505
air_id = air_stores[ind]
visitors_an = air_store_group.get_group(air_id).set_index('visit_date').drop('air_store_id', axis=1)

if air_id in list(air_reserve_group.groups.keys()):
    reserved = air_reserve_group.get_group(air_id)
    reserved_an = reserved['reserve_visitors'].groupby(reserved.visit_datetime.dt.floor('1h')).sum()

    plt.figure(figsize = [15, 5])
    plt.subplot(211)
    plt.plot(visitors_an.index, visitors_an.visitors)
    plt.xlim(['2016-01','2017-05'])

    plt.subplot(212)
    plt.plot(reserved_an.index, reserved_an.values)
    plt.xlim(['2016-01','2017-05'])
else:
    plt.figure(figsize = [15, 5])
    plt.plot(visitors_an.index, visitors_an.visitors)
    plt.xlim(['2016-01','2017-05'])

# %% [markdown]
# Что можно сделать?
# - сгруппировать ряды и привести к единичному формату;
# - обучить какие-то сходные модели;

# %%
hpg_info_df = pd.read_csv('./data/hpg_store_info.csv',index_col='hpg_store_id')
store_info = air_info_df.merge(pd.read_csv('./data/store_id_relation.csv', index_col='air_store_id'), 
                               left_index=True, right_index=True, how='left')

store_info = info.merge(hpg_info_df, left_on='hpg_store_id', right_index=True, how='left')
print(store_info.shape)
store_info.head()
# Out:
# (829, 9)
#                       air_genre_name                 air_area_name  \
# air_store_id
# air_0f0cdeee6c9bf3d7  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# air_7cc17a324ae5c7dc  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# air_fee8dcf4d619598e  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# air_a17f0778617c76e2  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# air_83db5aff8f50478e  Italian/French  Tōkyō-to Minato-ku Shibakōen
#
#                       latitude_x  longitude_x          hpg_store_id  \
# air_store_id
# air_0f0cdeee6c9bf3d7   34.695124   135.197852                   NaN
# air_7cc17a324ae5c7dc   34.695124   135.197852  hpg_9b38b9e13da6da27
# air_fee8dcf4d619598e   34.695124   135.197852                   NaN
# air_a17f0778617c76e2   34.695124   135.197852                   NaN
# air_83db5aff8f50478e   35.658068   139.751599                   NaN
#
#                      hpg_genre_name hpg_area_name  latitude_y  longitude_y
# air_store_id
# air_0f0cdeee6c9bf3d7            NaN           NaN         NaN          NaN
# air_7cc17a324ae5c7dc            NaN           NaN         NaN          NaN
# air_fee8dcf4d619598e            NaN           NaN         NaN          NaN
# air_a17f0778617c76e2            NaN           NaN         NaN          NaN
# air_83db5aff8f50478e            NaN           NaN         NaN          NaN

# %% [markdown]
# Посмотреть на распределение заведений по категориям. Возможно, для некоторых из них достаточно не двух, а одного параметра для полного описания.

# %%
tb = pd.crosstab(store_info.hpg_genre_name,store_info.air_genre_name, dropna=False)
tb
# Out:
# air_genre_name                Asian  Bar/Cocktail  Cafe/Sweets  \
# hpg_genre_name
# Amusement bar                     0             1            0
# Cafe                              0             1            0
# Creation                          0             0            0
# Creative Japanese food            0             0            0
# Grilled meat                      0             0            0
# International cuisine             0             2            0
# Italian                           0             0            0
# Japanese cuisine/Kaiseki          0             0            0
# Japanese food in general          0             0            0
# Japanese style                    0             0            0
# Karaoke                           0             1            0
# Okonomiyaki/Monja/Teppanyaki      0             0            0
# Party                             0             0            0
# Seafood                           0             0            0
# Spain Bar/Italian Bar             0             0            0
# Steak/Hamburger/Curry             0             0            0
#
# air_genre_name                Creative cuisine  Dining bar  \
# hpg_genre_name
# Amusement bar                                0           0
# Cafe                                         0           0
# Creation                                     0           1
# Creative Japanese food                       0           0
# Grilled meat                                 0           0
# International cuisine                        0           6
# Italian                                      0           3
# Japanese cuisine/Kaiseki                     0           0
# Japanese food in general                     0           0
# Japanese style                               0           0
# Karaoke                                      0           0
# Okonomiyaki/Monja/Teppanyaki                 0           0
# Party                                        0           0
# Seafood                                      0           1
# Spain Bar/Italian Bar                        0           2
# Steak/Hamburger/Curry                        0           0
#
# air_genre_name                International cuisine  Italian/French  Izakaya  \
# hpg_genre_name
# Amusement bar                                     0               0        0
# Cafe                                              0               0        0
# Creation                                          0               0        4
# Creative Japanese food                            0               0        1
# Grilled meat                                      0               0        0
# International cuisine                             0               0        3
# Italian                                           0               2        0
# Japanese cuisine/Kaiseki                          0               0        0
# Japanese food in general                          0               0        0
# Japanese style                                    0               0       16
# Karaoke                                           0               0        0
# Okonomiyaki/Monja/Teppanyaki                      0               0        0
# Party                                             0               0        0
# Seafood                                           0               0        2
# Spain Bar/Italian Bar                             0               3        2
# Steak/Hamburger/Curry                             0               0        0
#
# air_genre_name                Japanese food  Karaoke/Party  \
# hpg_genre_name
# Amusement bar                             0              0
# Cafe                                      0              0
# Creation                                  0              0
# Creative Japanese food                    0              0
# Grilled meat                              0              0
# International cuisine                     0              0
# Italian                                   0              0
# Japanese cuisine/Kaiseki                  1              0
# Japanese food in general                  1              0
# Japanese style                            3              0
# Karaoke                                   0              0
# Okonomiyaki/Monja/Teppanyaki              0              0
# Party                                     0              1
# Seafood                                   0              0
# Spain Bar/Italian Bar                     0              0
# Steak/Hamburger/Curry                     0              0
#
# air_genre_name                Okonomiyaki/Monja/Teppanyaki  Other  \
# hpg_genre_name
# Amusement bar                                            0      0
# Cafe                                                     0      0
# Creation                                                 0      0
# Creative Japanese food                                   0      0
# Grilled meat                                             0      0
# International cuisine                                    0      0
# Italian                                                  0      0
# Japanese cuisine/Kaiseki                                 0      0
# Japanese food in general                                 0      0
# Japanese style                                           0      0
# Karaoke                                                  0      0
# Okonomiyaki/Monja/Teppanyaki                             1      0
# Party                                                    0      0
# Seafood                                                  0      0
# Spain Bar/Italian Bar                                    0      0
# Steak/Hamburger/Curry                                    0      0
#
# air_genre_name                Western food  Yakiniku/Korean food
# hpg_genre_name
# Amusement bar                            0                     0
# Cafe                                     0                     0
# Creation                                 0                     0
# Creative Japanese food                   0                     0
# Grilled meat                             0                     3
# International cuisine                    0                     0
# Italian                                  0                     0
# Japanese cuisine/Kaiseki                 0                     0
# Japanese food in general                 0                     0
# Japanese style                           0                     1
# Karaoke                                  0                     0
# Okonomiyaki/Monja/Teppanyaki             0                     0
# Party                                    0                     0
# Seafood                                  0                     0
# Spain Bar/Italian Bar                    0                     0
# Steak/Hamburger/Curry                    1                     0

# %%
hpg_reserve_df = pd.read_csv('./data/hpg_reserve.csv', parse_dates=['visit_datetime','reserve_datetime'])
